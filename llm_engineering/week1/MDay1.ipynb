# %%
# %pip install google-generativeai
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
load_dotenv(override=True)
api_key = os.getenv("GEMINI_API_KEY")


if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("AIza"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
import google.generativeai as genai
genai.configure(api_key=api_key)

message = "Hello, Gemini! This is my first ever message to you."

model = genai.GenerativeModel("gemini-2.5-flash")

response = model.generate_content(message)

display(response.text)
# Out:
# "Hello! It's great to hear from you. Welcome!\n\nI'm here and ready when you are. How can I help you today?"

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# ...

# %%
mitul = fetch_website_contents("https://edwarddonner.com")
print(mitul)
# Out:
# Home - Edward Donner
#
# Home
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy DJing (but I’m badly out of practice), amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of
# Nebula.io
# . We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. Recruiters use our product today to source, understand, engage and manage talent. I’m previously the founder and CEO of AI startup untapt,
# acquired in 2021
# .
# We work with groundbreaking, proprietary LLMs verticalized for talent, we’ve
# patented
# ...

# %%
system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
def summarize(url):
    website = fetch_website_contents(url)
    model = genai.GenerativeModel('gemini-2.5-flash')
    
    # Combine system and user prompts for Gemini
    full_prompt = system_prompt + "\n\n" + user_prompt_prefix + website
    
    response = model.generate_content(full_prompt)
    return response.text

# %%
summary = summarize("https://edwarddonner.com")
display(Markdown(summary))
# Out:
# Welcome to Edward Donner's corner of the internet, where he's busy writing code, experimenting with LLMs (including an "arena" where they duke it out with diplomacy and deviousness – because that's a perfectly normal pastime), and occasionally pretending to understand Hacker News. He's also the CTO of an AI company, previously sold another AI startup, and somehow finds time for amateur DJing. So, basically, he's smarter than you, but at least he's honest about his DJ skills.
#
# As for his "posts," they're a thrilling peek into the future (or recent past, given the dates) of AI, covering everything from the "unique energy" of live AI events and putting AI into "production on AWS at scale" (because everything must be at scale) to curating the ultimate curriculum for becoming an AI overlord and executive briefings. Sounds like a blast if your idea of fun is a PowerPoint presentation with future dates.

# %%
summaryCNN = summarize("https://cnn.com")
display(Markdown(summaryCNN))
# Out:
# Well, hello there, CNN! Apparently, you're still in the business of delivering "Breaking News, Latest News and Videos," which is quite the revelation. You can browse everything from actual wars (Ukraine-Russia, Israel-Hamas) to the vastly important "Style" and "Travel" updates. They've got so many categories, you'll drown in content, and so many ways to consume it (Watch, Listen, Live TV), there's no escape. And just in case you forgot, they really, *really* want to know about your ad experience – probably more than they care about some of the actual news.

# %%
message = "Tell me a joke about programmers."
model = genai.GenerativeModel("gemini-2.5-flash")
response = model.generate_content(message)
display(response.text)
# Out:
# 'Why do programmers prefer dark mode?\n\nBecause light attracts bugs!'

# %%
system_prompt = "You are a helpful interview assistant that help student to to clear their technical interview doubts."

# %%
user_prompt="Give me some tips to clrear a technical interview. also give me some common questions asked in technical interviews."

# %%
def interview(technology):
    model = genai.GenerativeModel("gemini-2.5-flash")

    full_prompt = system_prompt + "\n\n" + user_prompt + "\n\nTechnology: " + technology

    response = model.generate_content(full_prompt)

    display(Markdown(response.text))

# %%
interview("Python")
# Out:
# Hello there! I'm glad to help you prepare for your technical interviews. Clearing a technical interview, especially in Python, involves a good grasp of the language, problem-solving skills, and effective communication.
#
# Let's break it down into actionable tips and common questions.
#
# ---
#
# ## Part 1: Tips to Clear a Technical Interview (Python Focus)
#
# ### A. Before the Interview
#
# 1.  **Understand the Job Description:**
#     *   What kind of Python role is it? (Web development, Data Science, DevOps, Scripting, etc.)
#     *   What libraries/frameworks are mentioned? (Django, Flask, FastAPI, NumPy, Pandas, etc.) This helps you tailor your preparation.
#     *   Are there specific domain knowledge requirements?
#
# 2.  **Master Python Fundamentals:**
#     *   **Syntax & Semantics:** Be comfortable writing clean, readable Python code.
# ...
